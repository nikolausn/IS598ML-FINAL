# %%
import os
import json
import numpy as np
from datetime import datetime
from nltk import word_tokenize
from nltk import sent_tokenize
from nltk import pos_tag
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
noun_tags = ['NN', 'NNS', 'NNP', 'NNPS']
def is_noun(pos):
    if pos in noun_tags:
        return True
    else:
        return False

# %%
def extract_nouns(text):
    nouns = []
    
    sentences = sent_tokenize(text)
    for sentence in sentences:
        tokens = word_tokenize(sentence)
        sentence_nouns = [word.lower() for (word, pos) in pos_tag(tokens) if is_noun(pos)] 
        nouns += sentence_nouns
    return ' '.join(nouns)

# %%
def get_top_level_categories(categories):
    specific_categories = categories.split()
    top_level_categories = set([category.split('.')[0] for category in specific_categories])
    
    return top_level_categories

# %%
# Training set: 2016
# Test set: 2017

categories = set()

train_X = []
train_Y = []
with open(os.path.join('data-by-year', '2016.json'), 'r') as f:
    for line in f:
        row = json.loads(line)['arXiv']
        year = datetime.strptime(row['created'],"%Y-%m-%d").year
        
        row_categories = get_top_level_categories(row['categories'])
        categories = categories.union(row_categories)

        train_X.append(extract_nouns(row['title'] + '\n ' + row['abstract']))
        train_Y.append(row_categories)

test_X = []
test_Y = []    
with open(os.path.join('data-by-year', '2017.json'), 'r') as f:
    for line in f:
        row = json.loads(line)['arXiv']
        year = datetime.strptime(row['created'],"%Y-%m-%d").year
        
        row_categories = get_top_level_categories(row['categories'])
        categories = categories.union(row_categories)

        test_X.append(extract_nouns(row['title'] + '\n ' + row['abstract']))
        test_Y.append(row_categories)

print(len(train_X))
print(len(test_X))
print(len(train_Y))
print(len(test_Y))
# Out:
# 113436
# 123781
# 113436
# 123781

# %%
from collections import defaultdict

word_counts_per_category = {}
word_doc_counts_per_category = {}

for i in range(len(train_Y)):
    words = train_X[i].split()
    unique_words = set(words)
    for category in train_Y[i]:
        if category not in word_counts_per_category:
            word_counts_per_category[category] = defaultdict(int)
            word_doc_counts_per_category[category] = defaultdict(int)
        for word in words:
            word_counts_per_category[category][word] += 1
        for word in unique_words:
            word_doc_counts_per_category[category][word] += 1

# %%
neg = set()
for category, word_freq in word_doc_counts_per_category.items():
    if category == 'physics':
        pos = set(word_freq.keys())
    else:
        neg = neg.union(word_freq.keys())
print(pos - neg)
print(word_doc_counts_per_category['econ'])
# Out:
# {'time-interleaved', 'k^+\\rightarrow', 'db/m', 'high-harmonic', 'rekarks', 'non-air', 'eyring', 'servomotor', 'nonclustered', 'pafe', 'solvionic', '\\alpha_l\\', 'ze-rey', 'ta_s^', 'tremor-location', 'hir', 'spta', 'arxiv:1508.03219', 'microtomograph', 'factin', 'extensions/corrections', '1-hexene', 'meccanica', '-7p~^', 'croissant', 'nicr', 'oncological', '-88', 'm_0g', 'fene-cr', 'ci\\^ensa\\c', 'polyolefin', 'hadisst', 'catsw', 'kawata', 'cole\\c', 'experiments5,6', 'sub-critical', 'soundboard', 'photopolymerization', 'r-asp', 'm3.0', 'fast-burning', 'peak/s', 'contribucion', 'double-distribution-function', 'sphps', 'apple-ii', 'osh-pt', 'td-casscf', 'beron-vera', 'analizamos', 'esrrs', 's/\\rd', 'conceptos', 'q=7500', 's_z=\\pm', 'teslatransformatoren', 'beale', 'dielectric-like', 'edel', 'astrologer', '/ingaas', 'beading', 'multi-penning-trap', 'verdet', 'circular-plane-jet', 't-506', 'pi-pi', 'spectral-domain', 'vpt2', 'c\\hbar', 'rayleigh-scattering', 'micro-mesh', 'gluon-', 'colourization', 'isovels', 'microtoroid', 'constant-convection-diffusion-reaction', 'blondeaux', 'jet-source', 'dechirper', 'hdie', 'downbursts', 'scintilator+wls', 'isep1', 'mashar', 'premixed', 'sin\\textsubscript', 'positive-action', 'parker-moffatt', 'wptm', 'z-wire', 'knncad', 'aef', 'drude-like', 'laser-guiding', 'tpiv', 'acceleration-deceleration', '\\omega/\\omega', 'rcv', 'dlsppws', 'semi-period', 'sitting', 'batuceper', 'cockcroft-walton', 'tall-tower', 'veen', 'calo', 'd3q7', 'reynolds-stress', 'yitterbium', 'klaps', 'brahe', 'air/glass/air', 'restults', 'constrained-transport', 'safronova', 'nuclear-test-ban', 'range-dependence', 'desynchronism', "'principle", 'principali', 'recirculating', 'ultra-broadband', 'sequenza', 'focs-2', 'mode-matching', 'au/si', 'nonsubstorm', 'z-pinches', 'h2/d2', 'reissner-nordst\\', 'location.the', 'self-fields', 'f_\\geq', 'overlap-add', 'quantera', 'metop', 'mls-em', 'ecrh', 'absorption-vs-position', 'surface-circuit-surface', 'nanodripping', 'regular-random', 'inhomogenity', 'counterstreaming', 'denlinger', 'lpmos', 'pinna', 'mentalist', 'leeward', 'massive-particle', 'vibrational-excitation', 'emanate', 'nanocylinder', 'egsnrc', 'maxwell/oldroyd-b', 'aaps', 'cross-shaped', 'mode-division', 'turbulent-influences', 'q_\\psi', 'w_phi', 'fluorosulfonyl', 'sesre', 'smart-aggregation', 'microbolometer', 'sonate', 'i\\simeq10^', 'methane-oxygen', 'pec-emp-cmt', 'panhandle', 'st\\in', "wardrop'", 'regcoil', 'k-integral', 'efimov-type', 'j1903+327', 'nano-membranes', '^+_3', 'avo', 'universalis', 'lucchese', 'of-bos', 'ps-pulses', '-amplitude', 'black-sholes', 'laforge', 'microjoule', 'tuck', 'cm-range', 'epicurean', 'minimal-valence-plus-core', 'solitary-waves', 'particolare', 'initiations', 'scomposizione', 'wavelength-to-time', 'detonability', 'e1983-e1992', 'lithium-bromine', 'thvs', 'hectare', 'dura', 'biggs', 'r1-r', 'lebt', 'linestrengths', 'scl3', 'raghav', 'poly-3-hydroxybutyrate', 'moditic', 'ceda', 'izacard', 'frequency-resolution', 'dissipatons', 'es-bgk', 'db/um', 'k=0.8', 'hyper-lithography', '+54\\rangle\\rightarrow|56,55', 'seamount', 'beppu-shimabara', '~100nm', 'j.~fluid', 'regionale', 'xshells', 'velocity-change', 'highend', 'lowly', 'dupage', 'reynolds-averaged', 'c-point', 'thinker', 're=2609', 'surface-waves', 'zeeman-coherence', 'icrh-', 'kinetic-equation', 'fslbm', 'meta-surfaces', 'propeller-type', 'saltating', 'ivdf', 'z=91', 'malik2010', 'tm010', 'm_p=\\sqrt', 'csernai', 'counterflows', 'sns-ts2', 'ca0.67mg0.33co3', 'wavelet/higher', 'contact-mode', '\\right|\\to', 'mistaking', 'indistinguishables', 'smsp', 'sintef', 'metamorphism', 'baml', 'pedestals', 'coxinel', 'bradyon-tachyon', 'pounds', 'low-migration-velocity', 'glass-on-glass', 'disease/information', 'pulsed-field-ionization', 'maxwell-fluid', 'n-dividing', 'neutron-gamma', 'bradyonic', 'lfzs', 'gulp', 'c_\\beta', 'm=li', 'proterozoic', 'clonners', 'intercycle', 'kerr-nonlinearity-mediated', 'polyene', 'permselectivity', 'sta ...
# defaultdict(<class 'int'>, {'feature': 1, 'shape': 2, 'size': 8, 'subpopulations': 3, 'properties': 6, 'means': 2, 'outcomes': 4, 'programs': 2, 'applications': 8, 'assumptions': 5, 'labor': 1, 'bootstrap': 6, 'tests': 5, 'treatment': 15, 'interest': 15, 'policy': 8, 'kaplan-meier': 2, 'market': 2, 'sample': 11, 'carlo': 10, 'monte': 10, 'duration': 2, 'heterogeneity': 6, 'unemployment': 1, 'software': 4, 'framework': 7, 'covariate': 3, 'null': 2, 'application': 9, 'variable': 7, 'effect': 15, 'open-source': 2, 'outcome': 7, 'alternatives': 2, 'restrictions': 2, 'values': 4, 'article': 2, 'integrals': 1, 'allocation': 1, 'assistance': 1, 'noncompliance': 1, 'study': 4, 'estimator': 12, 'average': 3, 'curse': 4, 'dimension': 3, 'birth': 2, 'uniform': 2, 'paper': 15, 'covariates': 8, 'band': 1, 'respect': 3, 'effects': 15, 'experiments': 4, 'confidence': 13, 'dimensionality': 4, 'robust': 2, 'situation': 1, 'function': 10, 'method': 10, 'number': 10, 'weights': 3, 'least': 1, '\\textquotedblleft': 1, 'regression': 13, 'orthogonal': 1, 'pure': 1, 'stage': 1, 'convergence': 4, 'approximation': 3, 'insights': 1, 'squares': 1, 'developments': 3, 'stopping': 1, 'post-selection': 1, 'design': 1, 'relevance': 1, 'literature': 6, 'machine': 4, 'matrix': 2, 'boosting\\textquotedblright\\': 1, 'l_2': 1, 'step': 2, 'sparse': 3, 'eigenvalue': 1, 'post-boosting\\textquotedblright': 1, 'projection': 3, 'learning': 4, 'results': 9, 'studies': 3, 'rules': 2, 'algorithm': 6, 'variables': 12, 'rate': 5, 'constant': 1, 'work': 2, 'aspects': 1, 'variant': 1, 'simulation': 7, 'lasso': 6, 'behavior': 1, 'comparison': 2, 'setting': 3, 'boosting': 1, 'greedy': 2, 'estimators': 10, 'sparsity': 1, 'parameter': 9, 'high': 1, 'point': 3, 'methods': 16, 'oracle': 2, 'property': 1, 'm-estimation': 1, 'technique': 2, 'segregation': 1, 'sets': 5, 'result': 4, 'model': 13, 'signals': 1, 'condition': 5, 'proof': 2, 'selection': 4, 'level': 5, 'sense': 1, 'change': 2, 'dynamics': 3, 'estimation': 13, 'need': 1, 'sub-populations': 1, 'coefficients': 6, 'distribution': 6, 'loss': 2, 'structure': 5, 'dimensional': 1, 'quantile': 7, 'trends': 2, 'shifts': 1, 'persistence': 1, 'fraction': 1, 'issue': 1, 'observations': 1, 'errors': 3, 'multivariate': 1, 'inflation': 2, 'dates': 1, 'usefulness': 1, 'regressors': 2, 'locations': 1, 'common': 1, 'simulations': 5, 'test': 6, 'system': 2, 'measures': 1, 'regime': 2, 'ratio': 2, 'hypothesis': 3, 'break': 1, 'limit': 3, 'multiple': 1, 'issues': 1, 'partitions': 1, 'requirement': 1, 'equations': 5, 'breaks': 1, 'estimates': 6, 'parameters': 12, 'latent': 1, 'time-variation': 1, 'merits': 2, 'models': 15, 'tightening': 1, 'tvp-vars': 1, 'indicators': 1, 'coefficient': 1, 'evidence': 3, 'inference': 12, 'forecast': 2, 'approach': 8, 'us': 2, 'term': 4, 'burden': 1, 'shocks': 1, 'autoregressions': 1, 'threshold': 1, 'components': 3, 'innovation': 1, 'benchmark': 1, 'gains': 3, 'macroeconomic': 2, 'process': 2, 'vector': 9, 'mixture': 1, 'rates': 2, 'data': 14, 'partially': 1, 'conditions': 6, 'interval': 1, 'response': 1, 'equality': 1, 'coverage': 4, 'program': 3, 'performance': 6, 'programming': 1, 'examples': 8, 'analogs': 1, 'procedure': 7, 'class': 4, 'projections': 1, 'processes': 1, 'moment': 5, 'profiling': 1, 'analysis': 8, 'feasibility': 2, 'degree': 1, 'problems': 4, 'statistical': 1, 'surface': 2, 'intervals': 8, 'value': 2, 'component': 1, 'solution': 3, 'accuracy': 3, 'probability': 2, 'calibration': 1, 'equalities': 2, 'optimization': 2, 'functions': 7, 'points': 1, 'relaxation': 1, 'identified': 2, 'subject': 2, 'networks': 1, 'regressions': 5, 'dense': 1, 'moments': 1, 'case': 3, 'network': 3, 'dummies': 1, 'panel': 3, 'setup': 1, 'workhorse': 1, 'time-varying': 1, 'addition': 2, 'factor': 3, 'computational': 1, 'extraction': 1, 'disturbances': 1, 'contexts': 1, 'k-step': 1, 'show': 1, 'factor-lasso': 1, 'factors': 3, 'validity': 6, 'part': 2, 'contribution': 1, 'confounding': 1, 'economic': 1, 'use': 6, 'terms' ...

# %%
word_doc_counts_per_category
# Out:
# {'cs': defaultdict(int,
#              {'people': 510,
#               'average': 307,
#               'digital': 122,
#               'size': 1622,
#               'quality': 1312,
#               'creativity': 24,
#               'seed': 64,
#               'respect': 866,
#               'matters': 30,
#               'images': 1601,
#               'approach': 5470,
#               'reasons': 175,
#               'approaches': 2005,
#               'things': 218,
#               'problems': 2804,
#               'ones': 524,
#               'substrate': 23,
#               'puzzles': 16,
#               'results': 7826,
#               'games': 439,
#               'work': 3815,
#               'clearer': 9,
#               'synaptic': 5,
#               'findings': 438,
#               'process': 2076,
#               'output': 882,
#               'dsns': 2,
#               'chess': 7,
#               'neural': 1182,
#               'photographs': 28,
#               'sequences': 575,
#               'players': 245,
#               'barter': 5,
#               'factor': 678,
#               'performances': 219,
#               'np-hard': 255,
#               'cycles': 142,
#               'approximation': 1040,
#               'contributions': 315,
#               'inapproximability': 17,
#               'set': 3067,
#               'algorithms': 3462,
#               'exchanges': 40,
#               'yield': 65,
#               'terminology': 26,
#               'vertex-disjoint': 5,
#               'length': 571,
#               'experiments': 2573,
#               'market': 228,
#               'theory': 1415,
#               'exchange': 237,
#               'cycle': 184,
#               'digraph': 30,
#               'simple': 156,
#               'problem': 6440,
#               'constraints': 1184,
#               'graph': 1730,
#               'weight': 310,
#               'clearing': 10,
#               'graphs': 1257,
#               'data': 6645,
#               'understanding': 590,
#               'skeleton-associated': 1,
#               'recognition': 1174,
#               'parts': 389,
#               'bag': 53,
#               'association': 186,
#               'shape': 337,
#               'descriptor': 90,
#               'feature': 1311,
#               'correspondence': 125,
#               'paper': 10851,
#               'benchmarks': 434,
#               'vs': 29,
#               'part': 805,
#               'ssc': 9,
#               'thickness': 20,
#               'svm': 139,
#               'framework': 3143,
#               'contour': 44,
#               'change': 310,
#               'skeleton': 32,
#               'classifier': 433,
#               'representations': 821,
#               'fragment': 83,
#               'vector': 925,
#               'context': 1243,
#               'descriptors': 152,
#               'structures': 791,
#               'distribution': 1402,
#               'information': 4407,
#               'features': 2228,
#               'way': 1559,
#               'safety': 253,
#               'anonymization': 14,
#               'applications': 2927,
#               'maintain': 13,
#               'cooperation': 151,
#               'infrastructure': 304,
#               'mischief': 1,
#               'privacy': 386,
#               'decentralized': 48,
#               'bounds': 1213,
#               'cost': 1359,
#               'purpose': 454,
#               'machines': 433,
#               'deploy': 4,
#               'value': 926,
#               'system': 4249,
#               'trustworthy': 3,
#               'centralized': 28,
#               'probability': 1379,
#               'database': 530,
#               'operator': 302,
#               'need': 668,
#               'owner': 23,
#               'makes': 4,
#               'systems': 3867,
#               'equivocation': 4,
#               'numbers': 337,
#               'internet': 532,
#               'identification': 484,
#               'composition': 213,
#               'benefit': 176,
#               'properties': 1740,
#               'lie': 46,
#               'field': 1070,
#               'effectiveness': 1126,
#               'syntax': 104,
#               'block': 428,
#               'excitement': 6,
#               'scenes': 208,
#               'position': 344,
#               'layout': 89,
#               'beforehand': 22,
#               'color': 216,
#               'scene': 377,
#               'simplest': 2,
#               'learning': 3207,
#               'attribute': 110,
#               "'things": 1,
#               'successes': 41,
#               'abstraction': 194,
#               'ratio': 610,
#               'effect': 677,
#               'illustrations': 12,
#               'types': 1059,
#               'proposals': 135,
#               'statements': 73,
#               'object': 606,
#               'identities': 75,
#               'estimators': 133,
#               '\\geqslant': 3,
#               'regression': 490,
#               'bound': 1280,
#               'perspective': 490,
#               'k': 500,
#               'tails': 15,
#               'generalization': 556,
#               'population': 280,
#               'hyper-parameters': 23,
#               'conditions': 1249,
#               'outcomes': 182,
#               'errors': 484,
#               'error': 1435,
#               'performance': 5444,
#               'heaviness': 1,
#               '_2': 28,
#               'keywords': 82,
#               'estimates': 315,
#               'ability': 761,
#               'model': 5746,
#               'inequalities': 127,
#               'moment': 101,
#               'analysis': 3991,
#               '<': 195,
#               'cross-validation': 34,
#               'bias-variance': 6,
#               'prediction': 1014,
#               'l_2': 18,
#               'simulations': 946,
#               'samples': 653,
#               'ga': 27,
#               'complexity': 2165,
#               'trade-off': 254,
#               'application': 1728,
#               'difference': 357,
#               'function': 2134,
#               'estimation': 1353,
#               'lasso': 52,
#               'l': 142,
#               'number': 4415,
#               '-consistent': 2,
#               'cases': 1239,
#               'concentration': 72,
#               'networks': 4578,
#               'statistics': 396,
#               'video': 700,
#               'flexibility': 251,
#               'flow': 533,
#               'models': 3633,
#               'evaluation': 1484,
#               'computation': 1095,
#               'recurrent': 418,
#               'attention': 847,
#               'success': 488,
#               'speed': 470,
#               'units': 327,
#               'amount': 773,
#               'sequence': 925,
#               'rnns': 102,
#               'operations': 641,
#               'phenomena': 179,
#               'progress': 334,
#               'speech': 325,
#               'range': 1026,
#               'computations': 293,
#               'knowledge': 1598,
#               'step': 814,
#               'modification': 167,
#               'language': 1461,
#               'rate': 1651,
#               'tasks': 1763,
#               'dependency': 206,
#               'architectures': 581,
#               'structure': 2138,
#               'capacity': 812,
#               'time': 4418,
#               'simplicity': 139,
#               'embeddings': 296,
#               'mathematicians': 16,
#               'cf': 28,
#               'science': 497,
#               'h.': 12,
#               'p.': 25,
#               '>': 307,
#               'corollary': 30,
#               'minc': 1,
#               'k\\to': 1,
#               'd.': 29,
#               'edelsbrunner': 2,
#               'criteria': 287,
#               'result': 1825,
#               '\\varphi': 2,
#               'cluster': 321,
#               'hanani-tutte': 4,
#               's.': 31,
#               'computer': 1074,
#               'corollaries': 14,
#               'repovs': 1,
#               'spiez': 1,
#               'stability': 413,
#               'a': 833,
#               'skopenkov': 1,
#               'van': 25,
#               'plane': 245,
#               'specialists': 12,
#               'notions': 171,
#               'intersections': 41,
#               'completeness': 87,
#               'survey': 385,
#               'obstruction': 13,
#               'approximability': 37,
#               'm.': 42,
#               'a.': 38,
#               'areas': 497,
#               'f': 287,
#               'area': 726,
#               'planarity': 13,
#               'torunczyk': 1,
#               'kampen': 1,
#               'r^2': 12,
#               'names': 70,
#               'scale': 582,
#               'combines': 93,
#               'methods': 3988,
#               'equivalence': 211,
#               'datasets': 1881,
#               'characteristics': 586,
#               'challenges': 891,
#               'task': 2129,
#               'certainty': 10,
#               'reviews': 71,
#               'sampling': 381,
#               'review': 260,
#               'relevance': 201,
#               'usage': 355,
#               'pack': 3,
#               'titles': 16,
#               'screening': 36,
#               'testing': 229,
#               'applicability': 254,
#               'use': 1990,
#               'test': 746,
#               'variability': 129,
#               'metrics': 534,
#               'citation': 118,
#               'representation': 1346,
#               'search': 967,
#               'algorithm': 5075,
#               'abstracts': 25,
#               'grouping': 45,
#               'importance': 550,
#               'method': 4836,
#               'cross': 84,
#               'validation': 229,
#               'platform': 483,
#               'steps': 488,
#               'rating': 63,
#               '%': 1642,
#               'citations': 57,
#               'study': 1878,
#               'load': 310,
#               'relationships': 352,
#               'e.g': 467,
#               'twitter': 230,
#               'osn': 14,
#               'tradeoffs': 85,
#               'online': 761,
#               'osns': 17,
#               'social': 380,
#               'updates': 181,
#               'resource': 561,
#               'participation': 86,
#               'provider': 93,
#               'cost-granularity': 1,
#               'crawling': 11,
#               'profiles': 135,
#               'apis': 37,
#               'api': 59,
#               'users': 1648,
#               'increments': 11,
#               'date': 137,
#               'resources': 759,
#               'selection': 766,
#               'provisioning': 50,
#               'accuracy': 1977,
#               'better': 46,
#               'release': 85,
#               'transactions': 80,
#               'providers': 160,
#               'e.g.': 634,
#               'words': 626,
#               'pointer': 23,
#               'achieves': 128,
#               'word': 603,
#               'states': 614,
#               'contexts': 222,
#               'recent': 152,
#               'deal': 43,
#               'art': 551,
#               'classifiers': 336,
#               'perplexity': 33,
#               'vocabularies': 26,
#               'lstm': 211,
#               'corpora': 145,
#               'network': 4868,
#               'treebank': 32,
#               'state': 1773,
#               'penn': 21,
#               'sentinel': 6,
#               'softmax': 32,
#               'wikitext': 1,
#               'mixture': 229,
#               'architecture': 1203,
#               'parameters': 1567,
#               'order': 2528,
#               'corpus': 310,
#               'behaviours': 69,
#               'programming': 745,
#               'functionality': 171,
#               'situations': 269,
#               'extension': 579,
#               'concepts': 428,
#               'sensors': 416,
#               'dsl': 20,
#               'concept': 733,
#               'lab': 38,
#               'domain': 1049,
#               'foundation': 125,
#               'addition': 1222,
#               'prelu': 1,
#               'advantages': 482,
#               'property': 656,
#               '//github.com/coldmooon/code-for-mpelu': 1,
#               'elu': 4,
#               'rectified': 10,
#               'convergence': 769,
#               'initialization': 128,
#               'deep': 842,
#               'https': 129,
#               'classification': 1701,
#               'training': 1548,
#               'exponential': 52,
#               'shares': 52,
#               'activation': 136,
#               'code': 979,
#               'parametric': 54,
#               'linear': 396,
#               'unit': 363,
#               'mpelu': 1,
#               'cifar-10/100': 3,
#               'multiple': 364,
#               'wider': 60,
#               'form': 998,
#               'distance': 868,
#               'brain': 209,
#               'earth': 34,
#               'disorder': 17,
#               'access': 1065,
#               'roc-curve': 1,
#               'spectrum': 375,
#               'spectra': 41,
#               'dataset': 1547,
#               'distributions': 625,
#               'development': 940,
#               'versus': 72,
#               'phenotypes': 8,
#               'connectomes': 5,
#               'simpler': 139,
#               'autism': 6,
#               'kernel': 387,
#               'emd': 7,
#               'mover': 9,
#               'advantage': 560,
#               'objects': 802,
#               'rgbd': 21,
#               'detection': 1620,
#               'works': 510,
#               'saliency': 79,
#               'propagation': 392,
#               'ambiguity': 80,
#               'priors': 103,
#               'map': 417,
#               'cnn': 520,
#               'background': 246,
#               'compactness': 18,
#               'level': 1237,
#               'input': 1560,
#               'challenging': 162,
#               'salient': 41,
#               'pixels': 167,
#               'contrast': 645,
#               'cues': 146,
#               'depth': 334,
#               'master': 49,
#               'vectors': 496,
#               'towards': 555,
#               'evaluations': 280,
#               'quantitative': 23,
#               'numerous': 8,
#               'image': 2058,
#               'efforts': 257,
#               'fusion': 228,
#               'collection': 493,
#               'services': 550,
#               'c': 347,
#               'dem': 7,
#               'health': 231,
#               'project': 286,
#               'place': 245,
#               'workflow': 49,
#               'b': 342,
#               'principles': 229,
#               'caregivers': 3,
#               'guidelines': 120,
#               'multitude': 38,
#               'report': 260,
#               'mechanisms': 492,
#               'environment': 835,
#               '@': 29,
#               'care': 94,
#               'multi-sensor': 16,
#               'objectives': 230,
#               'activities': 298,
#               'monitoring': 274,
#               'objective': 581,
#               'person': 199,
#               'professionals': 30,
#               'participants': 189,
#               'feedback': 454,
#               'status': 114,
#               'decision': 800,
#               'dementia': 3,
#               'context-aware': 21,
#               'hand': 520,
#               'assumption': 490,
#               'walkways': 1,
#               'index': 315,
#               'facilities': 67,
#               'researches': 46,
#               'movement': 189,
#               'design': 1805,
#               'width': 82,
#               'service': 655,
#               'considers': 50,
#               'interaction': 561,
#               'changes': 567,
#               'macroscopic': 31,
#               'buildings': 69,
#               'microscopic': 45,
#               'determination': 85,
#               'impact': 795,
#               'aggregation': 199,
#               'space': 1904,
#               'tracking': 318,
#               'module': 154,
#               'pedestrians': 42,
#               'linearity': 17,
#               'simulation': 1304,
#               'user': 1256,
#               'behavior': 946,
#               'criterion': 273,
#               'standards': 113,
#               'parameter': 724,
#               'within-subjects': 1,
#               'panning': 1,
#               'prototype': 241,
#               'enhancement': 144,
#               'capabilities': 403,
#               'visualization': 174,
#               'gain': 358,
#               'efficiency': 1258,
#               'reveals': 111,
#               'pathology': 18,
#               'workstations': 4,
#               'tissue': 45,
#               'practice': 678,
#               'pathologists': 11,
#               'strategies': 796,
#               'routine': 32,
#               'filtering': 241,
#               'reduction': 790,
#               'patterns': 816,
#               'microscope': 18,
#               'reveal': 26,
#               'gigapixel': 1,
#               'preference': 124,
#               'stain': 2,
#               'scale-space': 3,
#               'microscopes': 8,
#               'risks': 78,
#               'implementation': 1203,
#               'program': 608,
#               'ma': 9,
#               'illustration': 25,
#               'archer': 3,
#               'ea': 9,
#               'case': 2458,
#               'action': 411,
#               'enterprise': 55,
#               "'people": 1,
#               'aspects': 502,
#               'university': 140,
#               'example': 1074,
#               'logics': 105,
#               'culture': 35,
#               'research': 1944,
#               'morphogenetic': 1,
#               'role': 690,
#               'agency': 22,
#               'stakeholders': 52,
#               'shadowing': 11,
#               'point': 1152,
#               'protocol': 524,
#               'helper': 25,
#               'increases': 223,
#               'tier': 31,
#               'control': 1393,
#               'medium': 130,
#               'destination': 124,
#               'density': 500,
#               'distances': 232,
#               'poisson': 154,
#               'new': 359,
#               'priority': 91,
#               'presence': 663,
#               'coopmac': 3,
#               'upper': 76,
#               'helpers': 9,
#               'scheme': 1490,
#               'tiers': 20,
#               'source': 997,
#               'throughput': 449,
#               'nodes': 1116,
#               'vision': 687,
#               'kanade': 5,
#               'alignment': 222,
#               'compositional': 34,
#               'ic': 29,
#               'real-world': 279,
#               'connection': 390,
#               'inverse': 188,
#               'interest': 997,
#               'transformer': 26,
#               'topic': 378,
#               'communities': 285,
#               'stns': 2,
#               'spatial': 128,
#               'lucas': 6,
#               'lk': 5,
#               'ic-stns': 1,
#               'alignment/classification': 1,
#               'variant': 377,
#               'scaling': 212,
#               'decisions': 346,
#               'share': 345,
#               'insights': 479,
#               'month': 17,
#               'places': 78,
#               'day': 129,
#               'attractiveness': 24,
#               'emergence': 149,
#               'flickr': 28,
#               'scales': 261,
#               'events': 385,
#               'workers': 90,
#               'account': 516,
#               'cities': 101,
#               'country': 63,
#               'proxy': 54,
#               'planners': 34,
#               'p_1': 12,
#               '\\ldots': 91,
#               'p_l\\': 2,
#               'solution': 1803,
#               'edges': 527,
#               'fano': 6,
#               'characteristic': 81,
#               'dimension': 448,
#               'belongs': 39,
#               'primes': 22,
#               'p_2': 5,
#               'coding': 430,
#               'inner': 50,
#               'shows': 153,
#               'mac': 91,
#               'distortion': 150,
#               'communication': 1558,
#               'common': 55,
#               'sources': 519,
#               'region': 503,
#               'gaussian': 249,
#               'memoryless': 83,
#               'source-channel': 15,
#               'channel': 1264,
#               'outer': 76,
#               'correlated': 29,
#               'transmitting': 10,
#               'mds': 65,
#               'latency': 271,
#               'rates': 655,
#               'erasure': 73,
#               'placement': 159,
#               'probabilities': 287,
#               'disks': 21,
#               'modern': 79,
#               'caching': 163,
#               'request': 103,
#               'ends': 25,
#               'deployment': 338,
#               'failures': 166,
#               'files': 130,
#               'disk': 52,
#               'caches': 81,
#               'servers': 146,
#               'client': 91,
#               'clients': 81,
#               'improvement': 793,
#               'sprout': 1,
#               'open-source': 26,
#               'file': 121,
#               'storage': 497,
#               'requirements': 673,
#               'reliability': 307,
#               'codes': 724,
#               'novel': 633,
#               'cache': 169,
#               'chunks': 15,
#               'betweenness': 28,
#               'relies': 206,
#               'settings': 557,
#               'absolute': 44,
#               'technique': 1407,
#               'centralities': 6,
#               'centrality': 88,
#               '+o': 9,
#               'speedups': 63,
#               '\\theta': 81,
#               'paths': 380,
#               'kadabra': 1,
#               'random': 1089,
#               'contribution': 473,
#               'speedup': 128,
#               'subroutine': 17,
#               '|e|': 8,
#               'device': 337,
#               'iphone': 7,
#               'basift': 1,
#               'sdm': 6,
#               'scr': 1,
#               'approximated': 6,
#               'dense': 255,
#               'fast': 379,
#               'binary': 161,
#               'fft': 25,
#               'regressors': 10,
#               'sparse': 536,
#               'inspiration': 47,
#               'sift': 33,
#               'fps': 31,
#               'multi-language': 2,
#               'implementors': 3,
#               'optimizations': 108,
#               'singleton': 22,
#               'languages': 512,
#               'ruby': 6,
#               'modules': 146,
#               'implementations': 406,
#               'top': 202,
#               'classes': 783,
#               'bridge': 42,
#               'maglev': 1,
#               'machine': 1705,
#               'versa': 47,
#               'vice': 48,
#               'developers': 147,
#               'components': 670,
#               'software': 930,
#               'libraries': 98,
#               'vm': 23,
#               "maglev's": 1,
#               'smalltalk': 1,
#               'conventions': 11,
#               'meta': 20,
#               'collaboration': 126,
#               'gemstone/s': 1,
#               'scheduling': 270,
#               'realtime': 24,
#               'times': 717,
#               'link': 416,
#               'hybrid': 204,
#               'traffic': 578,
#               'cells': 203,
#               'scenario': 567,
#               'bss': 108,
#               'coordination': 155,
#               'communications': 509,
#               'stations': 244,
#               'hd': 35,
#               'base': 639,
#               'self-interference': 37,
#               'policy': 526,
#               'power': 1663,
#               'half': 82,
#               'operation': 497,
#               'full': 46,
#               'fd': 55,
#               'potential': 409,
#               'duplex': 33,
#               'interference': 529,
#               'geometric': 108,
#               'defaults': 3,
#               'equipment': 86,
#               'ues': 43,
#               'ue': 33,
#               'cancellation': 92,
#               'multi-cell': 20,
#               'converges': 116,
#               'cell': 294,
#               'allocation': 549,
#               'transmissions': 157,
#               'signal-to-noise': 69,
#               'closed-form': 50,
#               'optimal': 344,
#               'mimo-noma': 6,
#               'as': 29,
#               'sum-rates': 1,
#               'station': 272,
#               'noma': 35,
#               '-as': 4,
#               'expressions': 360,
#               'schemes': 831,
#               'snr': 151,
#               'regime': 261,
#               'gains': 370,
#               'joint': 207,
#               'antennas': 223,
#               'two-user': 13,
#               'fairness': 105,
#               'antenna': 172,
#               'aia-as': 2,
#               'logic': 520,
#               'gazebo': 3,
#               'collaborative': 64,
#               'table': 82,
#               'variants': 402,
#               'scenarios': 873,
#               'foreseen': 1,
#               'challenge': 783,
#               'assistants': 18,
#               'human-robot': 17,
#               'robots': 256,
#               'coverage': 312,
#               'checking': 134,
#               'pseudorandom': 18,
#               'interactions': 538,
#               'tests': 288,
#               'verification': 386,
#               'realism': 18,
#               'stimulation': 14,
#               'belief-desire-intention': 4,
#               'generation': 863,
#               'degree': 557,
#               'practicality': 39,
#               'intelligence': 275,
#               'ros': 17,
#               'bdi': 6,
#               'robot': 372,
#               'testbench': 3,
#               'ease': 61,
#               'improvements': 514,
#               'correctness': 203,
#               'assembly': 52,
#               'hri': 11,
#               'belief-desire-intentions': 1,
#               'agent': 391,
#               'issues': 601,
#               'operating': 170,
#               'agents': 534,
#               'nn': 35,
#               '-nnc': 1,
#               'target': 746,
#               'neighbor': 161,
#               'sets': 1205,
#               'class': 1519,
#               'neighborship': 1,
#               'symmetric': 70,
#               'labels': 437,
#               'world': 682,
#               'encodings': 31,
#               's': 309,
#               'values': 802,
#               'mutual': 24,
#               'nnc': 1,
#               'm': 312,
#               'ways': 375,
#               'partitioning': 111,
#               'type': 927,
#               'state-labelled': 1,
#               'markov': 499,
#               'formula': 214,
#               'chains': 151,
#               'time-bounded': 1,
#               'solutions': 1144,
#               'csl': 6,
#               'transition': 294,
#               'chain': 280,
#               'requirement': 258,
#               'trends': 169,
#               'diversity': 282,
#               'turn': 176,
#               'topics': 254,
#               'clustering': 455,
#               'web': 430,
#               'co-reference': 4,
#               'signal': 744,
#               'factors': 594,
#               'tdt5': 1,
#               'articles': 138,
#               'clusters': 349,
#               'content': 667,
#               'referents': 2,
#               'event': 317,
#               'entity': 201,
#               'documents': 246,
#               'co-occurrence': 47,
#               'news': 132,
#               'mining': 333,
#               'resolution': 399,
#               'entities': 246,
#               'mrdp': 1,
#               'argument': 110,
#               'q': 128,
#               'consequence': 208,
#               'hitherto': 10,
#               'literature': 1009,
#               'zero': 96,
#               'theorem': 445,
#               'equations': 375,
#               'division': 150,
#               'decidability': 68,
#               'robinson': 6,
#               'diophantine': 5,
#               'outperform': 33,
#               'cropping': 5,
#               'caltech-ucsd': 2,
#               'differences': 336,
#               'paradigm': 411,
#               'frames/sec': 3,
#               'layer': 607,
#               'explanation': 89,
#               'component': 526,
#               'contradictory': 3,
#               'categories': 326,
#               'deeper': 30,
#               'birds-200-2011': 1,
#               'interpretability': 78,
#               'categorization': 88,
#               'localization': 318,
#               'perturbation': 92,
#               'practices': 124,
#               'mobility': 191,
#               'independence': 140,
#               'psychology': 44,
#               'feed-backs': 1,
#               'ambient': 21,
#               'trend': 123,
#               'contextualization': 3,
#               'obstacles': 102,
#               'deficit': 14,
#               'quantification': 75,
#               'impairments': 31,
#               'adaptation': 289,
#               'usages': 12,
#               'service-visualization': 1,
#               'augmented': 28,
#               'hence': 284,
#               'situation-awareness': 1,
#               'gap': 492,
#               'choice': 409,
#               'bayesian': 156,
#               'conjugal': 2,
#               'stimuli': 41,
#               'citizens': 39,
#               'observability': 50,
#               'relates': 2,
#               'instrumentation': 22,
#               'governance': 22,
#               'trance': 1,
#               'relationship': 459,
#               'technology': 624,
#               'urban': 60,
#               'goals': 181,
#               'engagement/participation': 1,
#               'degradation': 123,
#               'annotation-richness': 1,
#               'opinions': 99,
#               'experience': 285,
#               'stipulation': 3,
#               'concern': 106,
#               'utility': 365,
#               'involvement': 28,
#               'scalability': 335,
#               'smart-city': 2,
#               'living': 38,
#               'advent': 61,
#               'reality': 131,
#               'aal': 2,
#               'consumption': 507,
#               'personalization': 24,
#               'paramount': 36,
#               'rejuvenation': 4,
#               'engagement': 66,
#               'disparate': 16,
#               'unobservability': 2,
#               'ict': 46,
#               'least': 85,
#               'section': 50,
#               'one-fourth': 1,
#               'post': 44,
#               'support': 661,
#               'transmission': 767,
#               'efficacy': 194,
#               'noise': 880,
#               'series': 548,
#               'corresponding': 65,
#               'square': 154,
#               'ground': 310,
#               'ls-svm': 2,
#               'line': 356,
#               'phases': 119,
#               'fault': 126,
#               'integration': 342,
#               'well': 66,
#               'fashion': 248,
#               'cancer': 81,
#               'therapies': 5,
#               'hypotheses': 115,
#               'response': 487,
#               'patients': 156,
#               'egfr': 2,
#               'factorization': 255,
#               'associations': 52,
#               'oncology': 3,
#               'medicine': 54,
#               'sample': 380,
#               'matrix': 1113,
#               'mek': 1,
#               'responses': 177,
#               ...}),
#  'cond-mat': defaultdict(int,
#              {'temperature': 3495,
#               'analogue': 91,
#               'interplay': 562,
#               'type': 663,
#               'collisions': 100,
#               'approximation': 948,
#               'proportional': 50,
#               'curvature': 224,
#               'matter': 761,
#               'field': 3921,
#               'specific': 39,
#               'effects': 2105,
#               'theory': 3358,
#               't': 778,
#               '\\nabla': 3,
#               'phenomena': 779,
#               'parity': 92,
#               'law': 495,
#               'transport': 1806,
#               '\\times': 39,
#               'responses': 131,
#               '\\bf': 54,
#               'fields': 1361,
#               '\\mu': 113,
#               'currents': 403,
#               'potential': 1223,
#               'e': 248,
#               'gradients': 112,
#               'berry': 174,
#               'wiedemann-franz': 19,
#               'corrections': 249,
#               'chiral': 84,
#               'coefficients': 316,
#               'relaxation': 824,
#               'time': 2212,
#               'nonlinear': 59,
#               'devices': 1121,
#               'tunnel': 202,
#               'magnetic': 193,
#               'spin-capacitance': 1,
#               'access': 182,
#               'decrease': 254,
#               'capacitor': 26,
#               'mtjs': 15,
#               'computation': 224,
#               '_2': 307,
#               'inversion': 324,
#               'relevance': 171,
#               'co/al': 1,
#               'o': 532,
#               'interfaces': 384,
#               'model': 4768,
#               'measurements': 1643,
#               '_3': 181,
#               'frequency': 965,
#               'resistor': 17,
#               'random': 496,
#               'blocks': 120,
#               '/nife': 1,
#               'mrams': 1,
#               'magnetocapacitance': 9,
#               'memories': 42,
#               'charge': 1515,
#               'accumulation': 96,
#               'junctions': 345,
#               'results': 4801,
#               'presence': 1630,
#               'circuit': 193,
#               'sign': 331,
#               'regime': 1474,
#               'effect': 2868,
#               'mtj': 25,
#               'high-frequency': 58,
#               'coupling': 1943,
#               'magnetoimpedance': 2,
#               'role': 1216,
#               'crucial': 5,
#               'magnetophase': 1,
#               'building': 145,
#               'split': 40,
#               'nano-manipulation': 1,
#               'dispersion': 545,
#               'pair': 484,
#               'phonon': 521,
#               'dependencies': 65,
#               'slow': 16,
#               'applications': 1470,
#               'design': 442,
#               'velocities': 114,
#               'class': 762,
#               'nano-waveguides': 1,
#               'fluxes': 58,
#               'modes': 996,
#               'modulations': 56,
#               'band-edges': 5,
#               'waveguides': 72,
#               'splitting': 318,
#               'cavity': 288,
#               'vortex': 275,
#               'vortices': 212,
#               'features': 920,
#               'plasmas': 22,
#               'dyson': 29,
#               'coulomb': 465,
#               'response': 1116,
#               'sum': 119,
#               'multiplicity': 7,
#               'interactions': 2058,
#               'result': 1027,
#               'analysis': 1658,
#               'case': 1646,
#               'phonons': 312,
#               'significance': 43,
#               'carrier': 490,
#               'screening': 154,
#               'rule': 162,
#               'gan': 64,
#               'relation': 617,
#               'components': 385,
#               'dielectric': 108,
#               'plasma-species': 1,
#               'phase': 3919,
#               'functions': 990,
#               'plasma': 112,
#               'behavior': 1945,
#               'polarization': 625,
#               'plasmon': 124,
#               'species': 212,
#               'equations': 804,
#               'channels': 259,
#               'data': 1307,
#               'couplings': 293,
#               'co': 244,
#               'properties': 4029,
#               'contributions': 382,
#               'models': 1437,
#               'competition': 270,
#               'potentials': 382,
#               'waals': 218,
#               'charges': 201,
#               'dipoles': 75,
#               'oligoglycine': 1,
#               'backbone': 35,
#               'der': 230,
#               'intrapeptide': 1,
#               'bonds': 163,
#               'length': 919,
#               'attractions': 15,
#               'changes': 692,
#               'balance': 148,
#               'stability': 679,
#               'solvation': 22,
#               'protein': 86,
#               'van': 260,
#               'contribution': 463,
#               'energy': 3677,
#               'terms': 1209,
#               'system': 3946,
#               'solvent': 74,
#               'peptides': 5,
#               'hydrogen': 195,
#               'oligoglycines': 1,
#               'peptide': 8,
#               'residues': 13,
#               'formation': 1020,
#               'collapse': 117,
#               'exclusion': 64,
#               'cases': 587,
#               'water': 311,
#               'order': 2668,
#               'solubility': 21,
#               'parameter': 1108,
#               'factor': 597,
#               'energies': 654,
#               'basis': 430,
#               'expansion': 535,
#               'metropolis': 27,
#               'vandermonde': 1,
#               'entropy': 584,
#               'neutralizing': 2,
#               'approach': 1945,
#               'correction': 173,
#               'characteristic': 119,
#               'power': 683,
#               'n=2,3': 2,
#               'term': 390,
#               '\\ldots,9': 1,
#               'crystallization': 73,
#               'boltzmann': 236,
#               'formula': 278,
#               'surface': 2154,
#               'n': 621,
#               'component': 323,
#               'background': 186,
#               'formalism': 459,
#               'sphere': 76,
#               '\\gamma=q^2/': 1,
#               'work': 1823,
#               'particles': 1069,
#               'exact': 52,
#               'method': 2040,
#               'values': 1044,
#               'limit': 1426,
#               'comparison': 501,
#               'euler': 21,
#               'determinant': 34,
#               'scaling': 630,
#               'quantum': 3734,
#               'ising': 426,
#               'investigations': 197,
#               'rise': 528,
#               'implications': 301,
#               'transition': 3095,
#               'inverse': 147,
#               'degeneracy': 221,
#               'nature': 1038,
#               'defects': 552,
#               'hamiltonian': 613,
#               'volume': 391,
#               'plaquette': 28,
#               'cuprate': 91,
#               'cacu': 11,
#               'substrates': 280,
#               'oxygen': 249,
#               'proximity': 224,
#               'nodal': 42,
#               'states': 3620,
#               'bi': 200,
#               'cuo': 66,
#               'sr': 193,
#               'strengths': 172,
#               'band': 1463,
#               '_': 734,
#               'orbitals': 225,
#               'substrate': 498,
#               'pairing': 245,
#               'superconductivity': 802,
#               'monolayer': 439,
#               'parameters': 1450,
#               'perturbation': 329,
#               'device': 672,
#               'freedom': 451,
#               'scattering': 856,
#               'wave': 730,
#               'couple': 42,
#               'characteristics': 469,
#               'electron': 1838,
#               'microscopy': 490,
#               'focusing': 27,
#               'examples': 335,
#               'degrees': 422,
#               'impurity': 399,
#               'graphene': 1032,
#               'calculations': 1885,
#               'speed': 201,
#               'conductance': 467,
#               'binding': 159,
#               'matrix': 647,
#               'tb': 53,
#               'experiment': 437,
#               'leq': 1,
#               'green': 256,
#               'gate': 289,
#               'versus': 83,
#               'strength': 971,
#               'projection': 75,
#               'equation': 1119,
#               'elements': 358,
#               'geometry': 607,
#               'function': 2251,
#               'equilibration': 59,
#               'example': 696,
#               'consumption': 30,
#               'hamiltonians': 176,
#               'systems': 3641,
#               'number': 1715,
#               'junction': 366,
#               'ribbon': 41,
#               'mapping': 168,
#               'showing': 7,
#               'trajectories': 162,
#               'wire': 120,
#               'memory': 280,
#               'tutte': 1,
#               'convergence': 122,
#               'confirmation': 25,
#               'series': 408,
#               'ode': 5,
#               'degree': 364,
#               'square-lattice': 3,
#               'odes': 2,
#               'solution': 653,
#               'primes': 3,
#               'high-': 7,
#               'contrast': 764,
#               'solutions': 506,
#               'powers': 50,
#               'susceptibility': 390,
#               'radius': 163,
#               'integer': 134,
#               'set': 514,
#               'fact': 300,
#               'cuprates': 170,
#               'superconductors': 707,
#               'interval': 91,
#               'fermion': 394,
#               'densities': 404,
#               'fluctuations': 1076,
#               'diagram': 756,
#               'materials': 2140,
#               'interaction': 2269,
#               'corresponds': 72,
#               'temperatures': 1251,
#               'asymmetry': 184,
#               'two-band': 31,
#               't_': 184,
#               'density': 2959,
#               'intra-band': 5,
#               'repulsion': 171,
#               'levels': 440,
#               'thermodynamics': 317,
#               'half-filling': 38,
#               'difference': 476,
#               'holes': 237,
#               'mixture': 169,
#               'meaning': 30,
#               'instance': 97,
#               'phenomenon': 467,
#               't_c': 190,
#               'structure': 3052,
#               'layers': 681,
#               'bands': 482,
#               'show': 336,
#               'colloids': 130,
#               'scale': 616,
#               'viscosity': 129,
#               'expression': 312,
#               'growth': 622,
#               'liquid': 775,
#               'dyre': 1,
#               'glass': 273,
#               'connectivity': 87,
#               'connection': 269,
#               'precursors': 24,
#               'agreement': 1050,
#               'experiments': 1604,
#               'macroscopic': 322,
#               'microscopic': 566,
#               'dynamics': 2733,
#               'vitrification': 5,
#               'structures': 1330,
#               'liquids': 290,
#               'description': 781,
#               'relaxations': 25,
#               'configurations': 365,
#               'ice': 95,
#               'nanomagnets': 37,
#               'analogues': 43,
#               'lattice': 1990,
#               'works': 101,
#               'mean': 139,
#               'artificial': 28,
#               'years': 215,
#               'square': 183,
#               'arrangements': 46,
#               'realization': 370,
#               'opportunity': 69,
#               'space': 1176,
#               'manifold': 77,
#               'consisting': 70,
#               'frustration': 158,
#               'arrays': 169,
#               'vacuum': 204,
#               'ground': 1071,
#               'studies': 950,
#               'nanostructures': 219,
#               'nanomagnetism': 2,
#               'physics': 1110,
#               'investigation': 388,
#               'i.e': 367,
#               'state': 3713,
#               'monopoles': 32,
#               'ten': 17,
#               'wealth': 24,
#               'frontier': 20,
#               'excitations': 844,
#               'points': 623,
#               'platform': 294,
#               'lattices': 480,
#               'phases': 1284,
#               'spin': 2613,
#               'signatures': 314,
#               'image': 105,
#               'efforts': 106,
#               'chirality': 153,
#               'manner': 155,
#               'networks': 438,
#               'size': 1190,
#               'decays': 57,
#               'spins': 507,
#               'carlo': 652,
#               'monte': 652,
#               'ferromagnetism': 113,
#               'vogel-fulcher': 4,
#               'simulations': 1854,
#               'network': 509,
#               '\\tau': 25,
#               'existence': 666,
#               'magnetisation': 36,
#               'potts': 43,
#               'relies': 48,
#               'magnonic': 13,
#               'means': 651,
#               'directions': 368,
#               'paper': 1023,
#               'control': 726,
#               'engineering': 320,
#               'width': 304,
#               'loop': 142,
#               'dms': 6,
#               'purpose': 126,
#               'thicknesses': 76,
#               'hysteresis': 186,
#               'apparatus': 28,
#               'applicability': 135,
#               'anti-dot': 1,
#               'mn': 159,
#               'semiconductors': 330,
#               'samples': 572,
#               'ga': 90,
#               '[': 600,
#               ']': 832,
#               'magnetometric': 1,
#               'ion': 278,
#               'change': 666,
#               'magnetization': 810,
#               'beam': 271,
#               'process': 1100,
#               'anisotropy': 644,
#               'saturation': 156,
#               'magnetometry': 53,
#               'study': 2026,
#               'ways': 145,
#               'film': 540,
#               'addition': 795,
#               'mechanism': 1022,
#               'gain': 114,
#               'electrons': 1039,
#               'reveals': 236,
#               'truncation': 28,
#               'occurrence': 137,
#               'distortion': 142,
#               'quantum-well': 5,
#               'induced': 74,
#               'pd': 49,
#               'exchange': 752,
#               'films': 771,
#               'indicates': 5,
#               'ultrathin': 12,
#               'rod': 26,
#               'finding': 150,
#               'confinement': 330,
#               'crystal': 736,
#               'stoner': 10,
#               'i.e.': 86,
#               'constant': 268,
#               'appearance': 210,
#               'flatter': 1,
#               'increase': 548,
#               'modulation': 256,
#               'metals': 327,
#               'magnetism': 314,
#               'criterion': 95,
#               'calculation': 529,
#               'measurement': 473,
#               'separation': 393,
#               'correlation': 970,
#               'front': 48,
#               'behaviour': 468,
#               'limiting': 32,
#               'vacancies': 170,
#               'a': 605,
#               'domain': 481,
#               'nonconserved': 1,
#               'region': 758,
#               'particle': 928,
#               'line': 471,
#               'weights': 56,
#               'dimensional': 93,
#               'exponents': 245,
#               'vanishes': 145,
#               'interface': 763,
#               'pure': 194,
#               'mixing': 143,
#               'tunneling': 258,
#               'segregation': 52,
#               'multilayer': 105,
#               'layer': 837,
#               'mn/fe': 4,
#               'cu': 271,
#               'fe': 418,
#               'hybridization': 189,
#               'microscope': 151,
#               'microscopy/spectroscopy': 20,
#               'fe-mn': 2,
#               'spectroscopic': 122,
#               'alloy': 123,
#               'atoms': 1034,
#               'afm/fm': 1,
#               'mode': 681,
#               'contribute': 25,
#               'supercurrent': 53,
#               'y_': 5,
#               'admittance': 6,
#               'flow': 541,
#               'shape': 502,
#               'resonance': 689,
#               '|\\delta|_': 1,
#               '\\exp': 17,
#               'dependence': 1528,
#               'gap': 1298,
#               'amplitude': 384,
#               '|\\delta': 2,
#               '\\omega': 48,
#               'superconductor': 567,
#               'condensate': 359,
#               'velocity': 533,
#               'maximum': 171,
#               'higgs': 36,
#               '\\delta': 86,
#               'situation': 159,
#               '\\propto': 41,
#               '\\mathbf': 31,
#               'ac': 119,
#               'oscillations': 484,
#               'v': 214,
#               'root': 45,
#               'al': 354,
#               'heat': 743,
#               'generalization': 170,
#               'efficiency': 510,
#               'evidence': 635,
#               'bounds': 100,
#               'validity': 178,
#               'engines': 52,
#               'arbitrary': 11,
#               'lett': 159,
#               'low-dissipation': 6,
#               'scales': 491,
#               'phys': 458,
#               'esposito': 2,
#               'loss': 247,
#               'rev': 332,
#               'sc': 102,
#               'ccm': 3,
#               "n\\'eel": 80,
#               'ordering': 325,
#               'first-order': 39,
#               '>': 360,
#               '=': 688,
#               'stiffness': 110,
#               'cubic': 46,
#               'ground-state': 40,
#               'cluster': 320,
#               'present': 64,
#               'transitions': 1187,
#               'heisenberg': 329,
#               'window': 110,
#               'diagrams': 190,
#               'body-centered': 1,
#               'coupled': 34,
#               'simple': 56,
#               'value': 1056,
#               'long-range': 107,
#               'j_1': 36,
#               'bcc': 56,
# ...
#               'equality': 1,
#               'coverage': 4,
#               'program': 3,
#               'performance': 6,
#               'programming': 1,
#               'examples': 8,
#               'analogs': 1,
#               'procedure': 7,
#               'class': 4,
#               'projections': 1,
#               'processes': 1,
#               'moment': 5,
#               'profiling': 1,
#               'analysis': 8,
#               'feasibility': 2,
#               'degree': 1,
#               'problems': 4,
#               'statistical': 1,
#               'surface': 2,
#               'intervals': 8,
#               'value': 2,
#               'component': 1,
#               'solution': 3,
#               'accuracy': 3,
#               'probability': 2,
#               'calibration': 1,
#               'equalities': 2,
#               'optimization': 2,
#               'functions': 7,
#               'points': 1,
#               'relaxation': 1,
#               'identified': 2,
#               'subject': 2,
#               'networks': 1,
#               'regressions': 5,
#               'dense': 1,
#               'moments': 1,
#               'case': 3,
#               'network': 3,
#               'dummies': 1,
#               'panel': 3,
#               'setup': 1,
#               'workhorse': 1,
#               'time-varying': 1,
#               'addition': 2,
#               'factor': 3,
#               'computational': 1,
#               'extraction': 1,
#               'disturbances': 1,
#               'contexts': 1,
#               'k-step': 1,
#               'show': 1,
#               'factor-lasso': 1,
#               'factors': 3,
#               'validity': 6,
#               'part': 2,
#               'contribution': 1,
#               'confounding': 1,
#               'economic': 1,
#               'use': 6,
#               'terms': 4,
#               'high-dimensional': 1,
#               'context': 1,
#               'arguments': 1,
#               'statements': 1,
#               'individual': 1,
#               'time': 7,
#               'identities': 1,
#               'governments': 1,
#               'austerity': 1,
#               'carbon': 1,
#               'climate': 1,
#               'bureaucracy': 1,
#               'bureaucracies': 1,
#               'agreement': 1,
#               'tax': 1,
#               'influence': 2,
#               'activists': 1,
#               'bandwagon': 1,
#               'opponents': 1,
#               'politicians': 1,
#               'environmentalists': 1,
#               'first-best': 1,
#               'priorities': 1,
#               'debate': 1,
#               'weaknesses': 1,
#               'complex': 1,
#               'research': 2,
#               'servants': 1,
#               'paris': 1,
#               'rents': 1,
#               'trade': 2,
#               'neyman': 1,
#               't': 1,
#               'dimensions': 3,
#               'bias': 5,
#               'weidner': 1,
#               'scott': 1,
#               'n': 2,
#               'logitfe': 1,
#               'fixed': 1,
#               'stata': 1,
#               'corrections': 1,
#               'commands': 2,
#               'probit': 1,
#               'problem': 5,
#               'probitfe': 1,
#               'panels': 1,
#               'fernandez-val': 1,
#               'collection': 4,
#               'quantification': 2,
#               'classroom': 2,
#               'ate': 2,
#               'target': 3,
#               'uncertainty': 3,
#               '\\r': 1,
#               'significance': 2,
#               'package': 4,
#               'theory': 6,
#               'cran': 2,
#               'testing': 2,
#               'penalization': 2,
#               'projects': 1,
#               'http': 1,
#               'metrics': 2,
#               '\\rpackage': 1,
#               'hdm': 2,
#               'atet': 2,
#               'extensions': 2,
#               'subcomponents': 2,
#               'demonstration': 2,
#               'r': 4,
#               'e.g.': 2,
#               'decisions': 1,
#               'indicator': 2,
#               'assumption': 2,
#               'index': 4,
#               'fact': 2,
#               'datasets': 1,
#               'challenge': 1,
#               'causal': 3,
#               'thousands': 1,
#               'score': 5,
#               'treatments': 3,
#               'none': 1,
#               'proxies': 2,
#               'fields': 1,
#               'surrogacy': 1,
#               'hundreds': 1,
#               'samples': 2,
#               'state': 2,
#               'researchers': 4,
#               'violations': 1,
#               'role': 1,
#               'chain': 1,
#               'information': 1,
#               'criterion': 2,
#               'surrogates': 1,
#               'frame': 1,
#               'surrogate': 1,
#               'combines': 1,
#               'adjustment': 2,
#               'settings': 5,
#               'error': 5,
#               'propensities': 1,
#               'assignment': 3,
#               'balancing': 1,
#               'approaches': 2,
#               'adjustments': 1,
#               'linearity': 1,
#               'propensity': 2,
#               'approximate': 1,
#               'contrast': 1,
#               'standard': 1,
#               'residual': 1,
#               'overlap': 1,
#               'health': 1,
#               'gap': 1,
#               'decomposition': 2,
#               'nature': 1,
#               'mean': 4,
#               'strategies': 2,
#               'utilization': 1,
#               'random': 3,
#               'care': 1,
#               'impact': 4,
#               'insurance': 1,
#               'simple': 1,
#               'modeling': 1,
#               'findings': 1,
#               'construction': 3,
#               'transformation': 1,
#               'interpretation': 2,
#               'complements': 1,
#               'discrete': 1,
#               'conjunction': 1,
#               'analyses': 3,
#               'scheme': 1,
#               'bands': 2,
#               'tools': 3,
#               'pwm': 1,
#               'capabilities': 1,
#               'characteristics': 2,
#               'population': 5,
#               'welfare': 1,
#               'partnership': 1,
#               'choice': 5,
#               'makers': 1,
#               'job': 1,
#               'conclude': 1,
#               'classes': 3,
#               'regret': 1,
#               'practice': 1,
#               'reasons': 1,
#               'bounds': 2,
#               'maximum': 2,
#               'model-selection': 1,
#               'exercise': 1,
#               'training': 2,
#               'jtpa': 2,
#               'rule': 1,
#               'penalized': 1,
#               'maximization': 1,
#               'maker': 1,
#               'discretion': 1,
#               'decision': 1,
#               'inequality': 3,
#               'act': 1,
#               'members': 2,
#               'sieve': 1,
#               'correlation': 1,
#               'loadings': 2,
#               'benchmarks': 1,
#               'p': 1,
#               'co-volatility': 1,
#               'series': 3,
#               'forecasting': 1,
#               'scores': 1,
#               'covariance': 1,
#               'log': 1,
#               'shrinkage': 1,
#               'elements': 1,
#               'yields': 1,
#               'log-returns': 1,
#               'variance': 2,
#               'portfolio': 1,
#               's': 1,
#               'towards': 1,
#               'pulls': 1,
#               'improves': 1,
#               'misspecification': 3,
#               'power': 4,
#               'bandwidths': 1,
#               'experiment': 2,
#               'space': 1,
#               'specification': 1,
#               'high-dimensionality': 2,
#               'nuisance': 2,
#               'costs': 1,
#               'budget': 1,
#               'census': 1,
#               'optimal': 1,
#               'trials': 1,
#               'control': 3,
#               'researcher': 1,
#               'individuals': 1,
#               'trial': 1,
#               'constraint': 2,
#               'randomized': 2,
#               'survey': 2,
#               'modification': 1,
#               'presence': 2,
#               'household': 2,
#               'precision': 1,
#               'improvements': 1,
#               'reductions': 1,
#               '%': 1,
#               'mode': 1,
#               'best': 1,
#               'bound': 1,
#               'manski': 1,
#               'transportation': 1,
#               'computation': 2,
#               'binary': 1,
#               'prediction': 3,
#               'subset': 2,
#               'exact': 1,
#               'integer': 1,
#               'risk': 3,
#               'ml': 2,
#               'set': 3,
#               'forest': 2,
#               'lifts': 1,
#               'overfitting': 1,
#               'ridge': 1,
#               'elasticities': 1,
#               'k-fold': 1,
#               'most': 1,
#               'demand': 2,
#               'trees': 1,
#               'nets': 1,
#               'supply': 1,
#               'splitting': 2,
#               'hybrids': 1,
#               'predictions': 1,
#               'aggregators': 1,
#               'regularization': 1,
#               'goal': 1,
#               'order': 2,
#               'statistical/machine': 1,
#               'placebo': 1,
#               'advances': 2,
#               'identification': 1,
#               'questions': 1,
#               'applied': 1,
#               'evaluation': 2,
#               'sensitivity': 1,
#               'discontinuity': 1,
#               'differences': 1,
#               'focus': 1,
#               'robustness': 3,
#               'units': 2,
#               'econometrics': 2,
#               'causality': 1,
#               'areas': 1,
#               'recommendations': 1,
#               'third': 1,
#               'forms': 1,
#               'post': 1,
#               'growth': 1,
#               'type': 3,
#               'states': 1,
#               'usa': 1,
#               'rise': 1,
#               'varieties': 1,
#               'united': 1,
#               'patterns': 1,
#               'finding': 1,
#               'unit': 1,
#               'periods': 1,
#               'barro': 1,
#               'viz': 1,
#               'ex': 1,
#               'sea': 1,
#               'specifications': 1,
#               'counties': 1,
#               'economy': 1,
#               'iii': 1,
#               'methodology': 1,
#               'differences-in-differences': 1,
#               'law': 2,
#               'ii': 2,
#               'consequence': 1,
#               'representation': 1,
#               'i': 2,
#               'censoring': 1,
#               'variety': 2,
#               'right-censored': 1,
#               'theorems': 2,
#               'numbers': 1,
#               'c++': 1,
#               'implementation': 1,
#               'grf': 1,
#               'quantity': 1,
#               'forests': 1,
#               'breiman': 1,
#               'weighting': 1,
#               'gaussian': 1,
#               'tasks': 1,
#               'likelihood': 3,
#               'kernel': 2,
#               'vertices': 1,
#               'motivating': 1,
#               'expenditure': 1,
#               'consumers': 1,
#               'distributions': 5,
#               'polyhedron': 1,
#               'goods': 1,
#               'utility': 1,
#               'constraints': 1,
#               'restriction': 1,
#               'u.k.': 1,
#               'frequentist': 2,
#               'airline': 1,
#               'cutoffs': 1,
#               'bernstein-von': 1,
#               'subvectors': 1,
#               'mises': 1,
#               'game': 1,
#               'entry': 1,
#               'bayesian': 2,
#               'criterions': 1,
#               'inequalities': 2,
#               'valid': 1,
#               'singularities': 1,
#               'qlr': 1,
#               'css': 1,
#               'boundary': 1,
#               'procedures': 1,
#               'dgps': 1,
#               'mc': 1,
#               'wilks': 1,
#               'flows': 1,
#               'gmm': 2,
#               'perspective': 1,
#               'efficiency': 1,
#               'review': 1,
#               'interactions': 1,
#               'ability': 1,
#               'stratification': 1,
#               'arises': 1,
#               'detail': 1,
#               'non-compliance': 1,
#               'complications': 1,
#               'groups': 1,
#               'estimating': 1,
#               '>': 1,
#               'website': 2,
#               'refinements': 1,
#               'benefits': 1,
#               'operation': 1,
#               'code': 2,
#               'edgeworth': 1,
#               'see': 1,
#               'expansions': 1,
#               'author': 2,
#               'mse': 1,
#               'explanatory': 1,
#               'forecasts': 1,
#               'gain': 1,
#               'observables': 1,
#               'diffusion': 1,
#               'bond': 1,
#               'spread': 1,
#               'powers': 1,
#               'consumption-wealth': 1,
#               'instance': 1,
#               'ratios': 1,
#               'premia': 1,
#               'advantage': 1,
#               'consistency': 2,
#               'probabilities': 1,
#               'square': 1,
#               'formula': 1,
#               'semiparametric': 1,
#               'lr': 1,
#               'meaning': 1,
#               '\\texttt': 1,
#               'introduction': 2,
#               'pointwise': 1,
#               'nonparametric': 1,
#               'approximations': 2,
#               'functionality': 2,
#               'derivatives': 1,
#               'displays': 2,
#               'obtains': 1,
#               'region': 1,
#               'implements': 1,
#               'quantreg.nonpar': 1,
#               'indices': 1,
#               'temperature': 1,
#               'ideal': 1,
#               'advantages': 1,
#               'trend': 1,
#               'heat': 1,
#               'fisher': 1,
#               'details': 1,
#               'price': 1,
#               'migration': 1,
#               'air': 1,
#               'island': 1,
#               'urbanization': 1,
#               '-statistics': 1,
#               'expression': 1,
#               'hutson': 1,
#               'endpoints': 1,
#               '\\log': 1,
#               'o': 1,
#               '^3\\bigr': 1,
#               ']': 1,
#               'smoothing': 1,
#               'quantiles': 1,
#               'l': 1,
#               'using': 1,
#               'o\\bigl': 1,
#               'normality': 2,
#               'dominance': 1,
#               'curvature': 1,
#               'criteria': 1,
#               'translog': 1,
#               'cost': 1,
#               'half-space': 1,
#               'cases': 1,
#               'decompositions': 1,
#               'chernozhukov': 1,
#               'counterfactual': 1,
#               'wage': 1,
#               'melly': 1,
#               "fern\\'andez-val": 1,
#               'possibly': 1,
#               'markov': 1,
#               'dynamic': 1,
#               'regimes': 1,
#               'misspecified': 1,
#               'time-inhomogeneous': 1,
#               'sequences': 1,
#               'basis': 1,
#               'chapter': 1,
#               'tails': 1,
#               'empirics': 1,
#               'determinants': 1,
#               'variations': 1,
#               'subsampling': 1,
#               'value-at-risk': 1,
#               'contagion': 2,
#               'auction': 1,
#               'production': 1,
#               'bassett': 1,
#               'applicability': 1,
#               'overview': 1,
#               'extremal': 1,
#               'frontiers': 1,
#               'i.e': 1,
#               'laws': 1,
#               'koenker': 1,
#               'contribute': 1,
#               'independence': 1,
#               'relationships': 1,
#               'regions': 1,
#               'systemic': 1,
#               'require': 1,
#               'contributions': 1,
#               'movement': 1,
#               'assets': 1,
#               'dependence': 1,
#               'ciqgms': 1,
#               'predictor': 1,
#               'qgms': 1,
#               'interdependence': 1,
#               'motivation': 1,
#               'events': 1,
#               'management': 1,
#               'returns': 1,
#               'penalty': 1,
#               'conditional': 1,
#               'difference': 1,
#               'tail': 1,
#               'continuum': 1,
#               'graphical': 1,
#               'pqgms': 1,
#               'techniques': 1})}

# %%
pos
# Out:
# {'%',
#  '\\cin',
#  'abf',
#  'ability',
#  'accuracy',
#  'achievability',
#  'actions',
#  'adaptation',
#  'addition',
#  'adversary',
#  'aid',
#  'alerts',
#  'algebraic',
#  'algorithm',
#  'alice',
#  'am',
#  'analysis',
#  'aperiodicity',
#  'application',
#  'applications',
#  'approximate',
#  'archiving',
#  'array',
#  'artificial',
#  'atoms',
#  'avoidance',
#  'awgn',
#  'beamformer',
#  'beamformers',
#  'beampattern',
#  'behavior',
#  'bit-error',
#  'bits',
#  'bob',
#  'border',
#  'bounds',
#  'camera',
#  'cameras',
#  'cars',
#  'case',
#  'channel',
#  'channels',
#  'circle',
#  'classes',
#  'classification',
#  'classifications',
#  'closest',
#  'codes',
#  'collaborate',
#  'communication',
#  'component',
#  'computation',
#  'concept',
#  'consideration',
#  'constraint',
#  'constructions',
#  'convnets',
#  'convolutional',
#  'coordination',
#  'correlates',
#  'costs',
#  'covariance',
#  'covert',
#  'cumbersome',
#  'data',
#  'dataset',
#  'deep',
#  'density',
#  'detecting',
#  'detection',
#  'detector',
#  'deviation',
#  'diagonal',
#  'distributed',
#  'distribution',
#  'dnns',
#  'ecm',
#  'edf',
#  'edge',
#  'efficient',
#  'effort',
#  'eigenvalues',
#  'end',
#  'envelope',
#  'environment',
#  'error',
#  'error-correction',
#  'error-prone',
#  'errors',
#  'estimation',
#  'estimator',
#  'examination',
#  'experiment',
#  'extensions',
#  'extractor',
#  'extractors',
#  'f0',
#  'factor',
#  'field',
#  'filter',
#  'floor',
#  'fm',
#  'frames',
#  'framework',
#  'frequency',
#  'function',
#  'gain',
#  'generation',
#  'graph',
#  'graphs',
#  'greedy',
#  'handle',
#  'high-quality',
#  'histograms',
#  'humans',
#  'image',
#  'images',
#  'implementation',
#  'improvement',
#  'inference',
#  'information',
#  'input',
#  'interferers',
#  'inversion',
#  'labeling',
#  'laplacian',
#  'learning',
#  'level',
#  'limitations',
#  'links',
#  'locations',
#  'lpd',
#  'machine',
#  'magnitude',
#  'matrix',
#  'measure',
#  'method',
#  'methods',
#  'model',
#  'modification',
#  'monitoring',
#  'multiple',
#  'multispectral',
#  'mvdr',
#  'narrowband',
#  'network',
#  'networks',
#  'neural',
#  'node',
#  'nodes',
#  'noise',
#  'noiseless',
#  'noisy',
#  'non',
#  'nulls',
#  'number',
#  'objects',
#  'observations',
#  'opportunity',
#  'optimization',
#  'order',
#  'ordering',
#  'orders',
#  'paper',
#  'parties',
#  'pattern',
#  'performance',
#  'periodicity',
#  'pixels',
#  'place',
#  'plane',
#  'planewave',
#  'polynomial',
#  'post',
#  'post-processing',
#  'potential',
#  'power',
#  'precision',
#  'presence',
#  'prior',
#  'priors',
#  'probability',
#  'problem',
#  'processing',
#  'product',
#  'projects',
#  'random',
#  'rank',
#  'rate',
#  'rates',
#  'ratio',
#  'recipient',
#  'refinement',
#  'reside',
#  'respect',
#  'restrictions',
#  'results',
#  'rgb',
#  'rms',
#  'role',
#  'root',
#  'sample',
#  'savings',
#  'scenario',
#  'scenarios',
#  'scene',
#  'scheme',
#  'scm',
#  'second-order',
#  'selection',
#  'sensor',
#  'sequences',
#  'set',
#  'settings',
#  'setup',
#  'shapshots',
#  'signal',
#  'signals',
#  'simulation',
#  'simulations',
#  'single-hop',
#  'site',
#  'size',
#  'smi',
#  'smooth',
#  'smoothness',
#  'snapshot',
#  'sparse',
#  'sparsity',
#  'spectrum',
#  'speech',
#  'squares',
#  'stall',
#  'storage',
#  'strategy',
#  'streams',
#  'structure',
#  'subsampling',
#  'subset',
#  'subsystems',
#  'surveillance',
#  'synthesis',
#  'system',
#  'target',
#  'targets',
#  'task',
#  'tasks',
#  'technique',
#  'temporal',
#  'terms',
#  'threats',
#  'throughput',
#  'topology',
#  'tracker',
#  'training',
#  'trajectories',
#  'trajectory',
#  'transmits',
#  'transmitter',
#  'uc',
#  'ula',
#  'unit',
#  'use',
#  'uses',
#  'vector',
#  'vertices',
#  'video',
#  'vis-nir',
#  'warden',
#  'wardens',
#  'wavelet',
#  'way',
#  'weights',
#  'willie',
#  'wireless',
#  'wng',
#  'work',
#  'yields',
#  'z-transform',
#  'zeros'}

# %%
# Training set: 2016
with open('2016.txt', 'w') as o:
    for text in train_X:
        o.write(text + '\n')
